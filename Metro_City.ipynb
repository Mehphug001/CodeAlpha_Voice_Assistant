# %% [markdown]
# <a href="https://colab.research.google.com/github/Mehphug001/CodeAlpha_Voice_Assistant/blob/main/Metro_City.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print(5+2)
# Out:
# 7

# %%
data=pd.read_csv('metro_cities_data.csv')
print(data)
# Out:
#                      city country  year  year_last_expansion  stations  \
# 0            Moscow Metro  Russia  1880                 1890       328
# 1          Shanghai Metro   China  1910                 1932        58
# 2       Mexico City Metro  Mexico  2011                 2011        80
# 3             Delhi Metro   India  1871                 1910       397
# 4    New York City Subway     USA  1935                 2022       256
# ..                    ...     ...   ...                  ...       ...
# 495     Mexico City Metro  Mexico  1935                 1993       101
# 496           Paris Métro  France  1959                 2004       431
# 497        Shanghai Metro   China  1953                 1983       243
# 498     Mexico City Metro  Mexico  1957                 2023       439
# 499           Paris Métro  France  1932                 1982       265
#
#      length_km  annual_ridership_mill         region
# 0       438.12                1756.10         Europe
# 1       366.99                2993.63      East Asia
# 2        99.26                 733.39  North America
# 3       157.34                 912.09     South Asia
# 4       709.52                 776.37  North America
# ..         ...                    ...            ...
# 495     179.35                1534.43  North America
# 496     765.60                2855.91         Europe
# 497     600.10                1284.17      East Asia
# 498     543.28                 386.63  North America
# 499     335.18                2743.03         Europe
#
# [500 rows x 8 columns]

# %%
print(data.columns)
# Out:
# Index(['city', 'country', 'year', 'year_last_expansion', 'stations',
#        'length_km', 'annual_ridership_mill', 'region'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   city                   500 non-null    object
#  1   country                500 non-null    object
#  2   year                   500 non-null    int64
#  3   year_last_expansion    500 non-null    int64
#  4   stations               500 non-null    int64
#  5   length_km              500 non-null    float64
#  6   annual_ridership_mill  500 non-null    float64
#  7   region                 500 non-null    object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 31.4+ KB

# %%
data.shape
# Out:
# (500, 8)

# %%
data.ndim
# Out:
# 2

# %%
data.head()
# Out:
#                    city country  year  year_last_expansion  stations  \
# 0          Moscow Metro  Russia  1880                 1890       328
# 1        Shanghai Metro   China  1910                 1932        58
# 2     Mexico City Metro  Mexico  2011                 2011        80
# 3           Delhi Metro   India  1871                 1910       397
# 4  New York City Subway     USA  1935                 2022       256
#
#    length_km  annual_ridership_mill         region
# 0     438.12                1756.10         Europe
# 1     366.99                2993.63      East Asia
# 2      99.26                 733.39  North America
# 3     157.34                 912.09     South Asia
# 4     709.52                 776.37  North America

# %%
data.describe()
# Out:
#               year  year_last_expansion    stations   length_km  \
# count   500.000000           500.000000  500.000000  500.000000
# mean   1938.984000          1983.586000  263.822000  408.746460
# std      46.677418            35.451378  136.148357  231.359538
# min    1863.000000          1874.000000   21.000000   20.190000
# 25%    1898.750000          1963.000000  149.750000  210.252500
# 50%    1938.000000          1994.000000  254.500000  406.935000
# 75%    1981.250000          2012.000000  386.000000  618.470000
# max    2020.000000          2025.000000  499.000000  795.830000
#
#        annual_ridership_mill
# count             500.000000
# mean             1512.825720
# std               852.790509
# min                42.720000
# 25%               756.717500
# 50%              1506.245000
# 75%              2287.870000
# max              2993.630000
